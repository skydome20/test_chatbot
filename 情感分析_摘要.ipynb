# %%
# Positive value + textRank summary
# %run main.py
# Out:
# Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# Loading model cost 2.265 seconds.
# Prefix dict has been built succesfully.
# Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# 2017-03-09 12:33:32,912 : DEBUG : Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# 2017-03-09 12:33:32,923 : DEBUG : Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# Loading model cost 6.760 seconds.
# 2017-03-09 12:33:39,683 : DEBUG : Loading model cost 6.760 seconds.
# Prefix dict has been built succesfully.
# 2017-03-09 12:33:39,688 : DEBUG : Prefix dict has been built succesfully.
# Positive Articles
#
# 【論文造假案台大：下月中有初步結果】 0.98920629872061
# ---台灣大學教授郭明良涉嫌論文造假
# ---楊泮池表示
# ---校內調查在下個月中旬會有初步結果
# ...

# %%
# Negative value + textRank summary
# %run main.py
# Out:
# Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# Loading model cost 1.900 seconds.
# Prefix dict has been built succesfully.
# Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# 2017-03-09 12:35:55,372 : DEBUG : Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# 2017-03-09 12:35:55,387 : DEBUG : Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# Loading model cost 3.479 seconds.
# 2017-03-09 12:35:58,866 : DEBUG : Loading model cost 3.479 seconds.
# Prefix dict has been built succesfully.
# 2017-03-09 12:35:58,876 : DEBUG : Prefix dict has been built succesfully.
# Negative Articles
#
# 【【論文造假】遭解聘台大美女教授張正琪泣訴是「代罪羔羊」】 2.5492941091442844e-12
# ---遭懲處最重的是台大口腔生物科學研究所美女教授張正琪
# ...
