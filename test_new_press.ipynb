# %%
# %run test_main.py
# Out:
# Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# Loading model cost 3.360 seconds.
# Prefix dict has been built succesfully.
# Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# 2017-02-24 12:58:19,138 : DEBUG : Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# 2017-02-24 12:58:19,149 : DEBUG : Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# Loading model cost 5.572 seconds.
# 2017-02-24 12:58:24,721 : DEBUG : Loading model cost 5.572 seconds.
# Prefix dict has been built succesfully.
# 2017-02-24 12:58:24,733 : DEBUG : Prefix dict has been built succesfully.
# 2017-02-24 12:58:43,011 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# ...

# %%
# %run test_main.py
# Out:
# 2017-02-24 12:56:20,817 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2017-02-24 12:56:20,944 : INFO : built Dictionary(13421 unique tokens: ['目標', '號往', '直率', '社經地位', '簽下']...) from 172 documents (total 68042 corpus positions)
# The original news: 172
# 2017-02-24 12:56:21,059 : INFO : collecting document frequencies
# 2017-02-24 12:56:21,074 : INFO : PROGRESS: processing document #0
# 2017-02-24 12:56:21,109 : INFO : calculating IDF weights for 172 documents and 13420 features (44624 matrix non-zeros)
# 2017-02-24 12:56:21,145 : INFO : using serial LSI version on this node
# 2017-02-24 12:56:21,152 : INFO : updating model with new documents
# 2017-02-24 12:56:21,300 : INFO : preparing a new chunk of documents
# 2017-02-24 12:56:21,339 : INFO : using 100 extra samples and 2 power iterations
# 2017-02-24 12:56:21,346 : INFO : 1st phase: constructing (13421, 110) action matrix
# 2017-02-24 12:56:21,369 : INFO : orthonormalizing (13421, 110) action matrix
# ...
