# %%
# %run main.py # "川普當總統的影響" (搜尋：關鍵字聯集)
# Out:
# Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# Loading model cost 1.570 seconds.
# Prefix dict has been built succesfully.
# The question is : 川普當總統的影響
# 1st keywords:['川普', '當', '總統', '影響']
# News Parsing Starts : ['川普', '當', '總統', '影響']
# (新聞爬蟲進行中)
#
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ------------------------------------------------------------------------------------------------
# (新聞標題※摘要※超連結)
#
# 【不出讓集團所有權川普又打破了一個美國總統的慣例】
# (1)這些產業將被置入一個信託基金
# (2)」川普在記者會上說：「我不喜歡這樣做給人造成的印象
# (3)川普的產業將被置入一個信託基金
# http://udn.com/news/story/5/2224981
#
# 【特派專欄美國總統生活有如楚門的世界】
# (1)美國總統歐巴馬剛當選時、並不適應這一採訪模式
# (2)美國總統不一定在每個場合都接受訪問或發言
# (3)沒有哪一位美國總統能剝奪白宮特派員協會（WHCA）和「西廂」新聞室協調出來的「隨行採訪供稿制」（pool report）
# ...

# %%
# %run main.py # "川普當總統的影響" (搜尋：關鍵字交集)
# Out:
# Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# Dumping model to file cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# Loading model cost 1.762 seconds.
# Prefix dict has been built succesfully.
# The question is : 川普當總統的影響
# 1st keywords:['川普', '當', '總統', '影響']
# News Parsing Starts : ['川普', '當', '總統', '影響']
# (新聞爬蟲進行中)
#
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
#
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
#
# ...Parsing...
# ------------------------------------------------------------------------------------------------
# (新聞標題※摘要※超連結)
#
# 【歐巴馬籲川普：別把總統當家族企業經營】
# (1)歐巴馬也提到俄羅斯企圖影響2016美國總統大選的網路攻擊
# (2)美國總統歐巴馬
# (3)卸任前忠告 歐巴馬：川普別把白宮當家族企業分享分享分享留言列印A-A+2017-01-09 15:49經濟日報 記者鍾詠翔╱即時報導 美國總統歐巴馬本周將在芝加哥發表告別演說
# https://udn.com/news/story/6813/2219063
#
# 【川普記者會摃上CNN 與記者火爆對嗆[影]】
# (1)中央社記者黃兆平紐約攝 106年1月12日被稱為「推特總統」的川普在副總統當選人彭斯及兒女們陪同下出席記者會
# (2)斥責情報單位及媒體處理「假新聞」不當
# ...

# %%
# %run main.py # "一例一休的影響" (搜尋：關鍵字聯集)
# Out:
# Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# Loading model cost 1.393 seconds.
# Prefix dict has been built succesfully.
# The question is : 一例一休的影響
# 1st keywords:['一例', '一休', '影響']
# News Parsing Starts : ['一例', '一休', '影響']
# (新聞爬蟲進行中)
#
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ------------------------------------------------------------------------------------------------
# (新聞標題※摘要※超連結)
#
# 【工總公開信「搶救一例一休」：放寬加班時數、調整變形工時】
# (1)包括「訪查」、「協助」、「調適期」及「彈性工時」等
# (2)被認為是政府、勞工及資方「三輸」的局面
# (3)勞動新制是否「三輸」
# http://news.ltn.com.tw/news/focus/paper/1070177
#
# 【一例一休造成物價上漲？ 林全：外界炒作】
# (1)做了不恰當回應
# (2)勞基法修正通過後
# (3)勞基法修正通過後
# http://news.ltn.com.tw/news/life/breakingnews/1945159
#
# 【一例一休警衛不足衝擊校園安全】
# (1)各級學校技工、司機、工友、廚工、警衛、臨時人員均適用《勞基法》
# ...

# %%
# %run main.py # "一例一休的影響" (搜尋：關鍵字交集)
# Out:
# Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# Loading model cost 1.896 seconds.
# Prefix dict has been built succesfully.
# The question is : 一例一休的影響
# 1st keywords:['一例', '一休', '影響']
# News Parsing Starts : ['一例', '一休', '影響']
# (新聞爬蟲進行中)
#
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
#
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ------------------------------------------------------------------------------------------------
# (新聞標題※摘要※超連結)
#
# 【一例一休警衛不足衝擊校園安全】
# ...

# %%
# %run main.py # "蔡英文最近的動向" (搜尋：關鍵字交集)
# Out:
# Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# Loading model cost 1.211 seconds.
# Prefix dict has been built succesfully.
# The question is : 蔡英文最近的動向
# 1st keywords:['蔡英文', '最近', '動向']
# News Parsing Starts : ['蔡英文', '最近', '動向']
# (新聞爬蟲進行中)
#
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ------------------------------------------------------------------------------------------------
# (新聞標題※摘要※超連結)
#
# 【當面提扁特赦辜寬敏：蔡英文沒講話】
# (1)「扁特赦的問題
# (2)蔡英文的特點是她不講話
# (3)獨派大老、總統府資政辜寬敏今在出席其創辦的新台灣和平基金會「台灣研究博碩士論文獎頒獎典禮」前透露
# ...

# %%
# %run main.py # "蔡英文最近的動向" (搜尋：關鍵字聯集)
# Out:
# Building prefix dict from /home/skydome20/Desktop/dbot/dbot.py3/jieba_dict/dict.txt.big ...
# Loading model from cache /tmp/jieba.u300776cf1c5f564361e07846b411a882.cache
# Loading model cost 2.766 seconds.
# Prefix dict has been built succesfully.
# The question is : 蔡英文最近的動向
# 1st keywords:['蔡英文', '最近', '動向']
# News Parsing Starts : ['蔡英文', '最近', '動向']
# (新聞爬蟲進行中)
#
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ...Parsing...
# ------------------------------------------------------------------------------------------------
# (新聞標題※摘要※超連結)
#
# 【當面提扁特赦辜寬敏：蔡英文沒講話】
# (1)「扁特赦的問題
# (2)蔡英文的特點是她不講話
# (3)獨派大老、總統府資政辜寬敏今在出席其創辦的新台灣和平基金會「台灣研究博碩士論文獎頒獎典禮」前透露
# ...
